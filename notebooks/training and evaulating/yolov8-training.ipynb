# %%
# Clone the ultralytics repository
! git clone https://github.com/ultralytics/ultralytics
# Navigate to the cloned directory
# %cd ultralytics
# Install the package in editable mode for development
# %pip install -e .

# %%
# %pip install comet_ml --quiet
impoe-rt comet_ml
import torch
comet_ml.init(project_name='kaggle-yolov8')

# %%
# !wandb disabled

# %%
# !yolo train data=/kaggle/input/files-for-data/train_data.yaml model=yolov8n.pt epochs=50

# %%
! yolo help

# %%
! time yolo predict model=/kaggle/working/ultralytics/runs/detect/train/weights/best.pt source=/kaggle/input/photos/shutterstock_342463247-920x920.jpg imgsz=640

# %%
# !yolo detect val data=/kaggle/input/files-for-data/data_for_eval.yaml model=/kaggle/working/ultralytics/runs/detect/train/weights/best.pt
