# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks

# %%
# %pip install comet_ml --quiet
import comet_mle-
comet_ml.init(project_name='kaggle-yolov5')

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /kaggle/input/file-for-training/train_data.yaml --weights yolov5s.pt --cache

# %%
! time python detect.py --weights /kaggle/working/yolov5/runs/train/exp/weights/best.pt --source /kaggle/input/photos/shutterstock_342463247-920x920.jpg --img 640

# %%
# here you can find the metrics for evaluation
! python val.py --weights /kaggle/working/yolov5/runs/train/exp/weights/best.pt --data /kaggle/input/files-for-eval/data_for_eval.yaml --img 640
